# %% [markdown]
# # CIGRE TB 880 - 2022
# ## Power cable rating examples for calculation tool verification
#
# Reference IEC standards:
# - "IEC 60287-1-1, Electric Cables - Calculation of the Current Rating - Part 1-1: Current Rating Equations (100 % load factor) and Calculation of Losses – General", IEC,  2014-11.
# - "IEC 60287-2-1, Electric Cables – Calculation of the Current Rating – Part 2-1: Thermal Resistance – Calculation of Thermal Resistance, Edition 2.0", IEC, 2015-2.

# %%
# Import libraries
import math as mt
import numpy as np
#import pandas as pd
import matplotlib
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt

# %% [markdown]
# # 4. Introductory Case study 0
#
# <div>
# <img src="./img/img4_cs05.png" width="400"/> <img src="./img/img6_numbFlat.png" width="200"/>
# </div>
#
# - 3: Outer cable lagging phase
# - 1: Central cable
# - 2: Outer cable leading phase
#
# **Input data:**

# %%
# 4.2.1 Grid parameters

U = 132 #[kv] Voltage level
f = 50 #[Hz] Frequency

# %% [markdown]
# <div>
# <img src="./img/img2_xlpe132kV.png" width="300"/> <img src="./img/img3_cross.png" width="450"/>
# </div>

# %%
# 4.2.2 Cable parameters

# List of the cable composition: [Conductor, Conductor_screen, XLPE_insulation, Insulation_screen, Sheath, Oversheath]
thk = [0, 1.5, 15.5, 1.3, 0.8, 3.5] #[mm] Thickness of the layer
dia = [0]*6 #[mm] Diammeter after the layer
dia[0] = 30.3 #[mm] Conductor diameter (630 mm2)

for i in range(1,len(dia)):
    dia[i] = dia[i-1] + 2*thk[i]

# Conductor
R_0 = 28.3e-6 #[Ohm/m] DC resistance at 20°C. From IEC 60228 Table 2
alpha_20 = 3.93e-3 #[K^-1] Temperature coefficient. From IEC 60287-1-1 Table 1 (Copper)
k_s = 1 # Skin effect coefficient (round stranded conductor and extruded insulation system). From IEC 60287-1-1 Table 2
k_p = 1 # Proximity effect coefficient (round stranded conductor and extruded insulation system). From IEC 60287-1-1 Table 2

# Insulation layer
epsilon = 2.5 # Relative permittivity. From IEC 60287-1-1 Table 3
tan_delta = 0.001 # Loss factor. From IEC 60287-1-1 Table 3
rho_i = 3.5 #[Km/W] Thermal resistivity. From CIGRE TB 640 Table 1
rho_sc = 2.5 #[Km/W] Thermal resistivity screen (semi-conducting layer). CIGRE WG B1.56, IEC 60949

# Metal sheath
t_s = thk[4] #[mm] From Manufacturer datasheet
rho_s_20 = 2.84e-8 #[Ohm/m] Resistivity at 20°c. From IEC 60287-1-1 Table 1
alpha_s_20 = 4.03e-3 #[K^-1] Temperature coefficient. From IEC 60287-1-1 Table 1 (Aluminium)

# Oversheath
rho_Tos = 3.5 #[Km/W] Thermal resistivity. From IEC 60287-2-1 Table 1

# %%
# 4.2.5 Operating conditions

theta_c_max = 90 #[°C] Maximum operating temperature of conductor. User
theta_air = 25 #[°C] Maximum air temperature
theta_a = 25 #[°C] Ambient ground temperature. From IEC 60287-3-1 Section 3.2.1
rho_Tsoil = 1 #[Km/W] Thermal resistivity. From IEC 60287-3-1 Section 3.2.2

# %% [markdown]
# **IEC 60287-2-1, Electric Cables - Calculation of the Current Rating - Part 2-1: Thermal Resistance - Calculation of Thermal Resistance. Table 2**
#
# <div>
# <img src="./img/img5_2-1_Table2.png" width="500"/>
# </div>

# %%
# 4.10.1.1 Installation

Z = 0.62 # From IEC 60287-2-1 Table 2
E = 1.95
g = 0.25

# %%
# Unfilled trough external dimensions and number of cables

tr_deep = 0.360 #[m]
tr_wide = 0.550 #[m]
p = tr_deep*2+tr_wide #[m] Part of the trough perimeter which is effective for heat dissipation

NC = 3 # Amount of cables laid into the trough

# %% [markdown]
# ## 4.10 CASE #0-5: Sub-case study with cables in an unfilled trough
#
# ### 4.10.7 Variant with non-neglected eddy-current losses
#
# This option was adopted by the CIGRE WG B1.56, not to neglect the eddy-current losses when the metal sheaths are bonded at both ends of an electrical section (Guidance Point 6).

# %% [markdown]
# ### 4.4.1 Capacitance
#
# $ C = \frac{\epsilon}{18\ln(\frac{D_i}{d_c})} 10^{-9} $ (F/m). From IEC 60287-1-1 Section 2.2

# %%
# 4.4.1 Capacitance

d_c = dia[1] #[mm] diameter of conductor, including screen, if any
D_i = dia[2] #[mm] external diameter of the insulation (excluding screen)

C = (epsilon/(18*mt.log(D_i/d_c)))*1e-9 #[F/m] From IEC 60287-1-1 Section 2.2
print("C = %.10E F/m" % C)
# Out:
# C = 2.1107662202E-10 F/m

# %%
# 4.4.2 Reactance

omega = 2*mt.pi*f #[rad/s] Angular frequency
s = dia[5] #[mm] distance between conductor axes in the electrical section being considered
d = D_i + 2*thk[3] + thk[4] #[mm] mean diameter of the sheath

X = 2*omega*1e-7*mt.log(2*s/d) #[Ohm/m] From IEC 60287-1-1 Section 2.3.3. Reactance of sheath or screen per unit length of cable for two adjacent single-core cables

# 4.8.1.1 Reactance
X_m = 2*omega*1e-7*mt.log(2) #[Ohm/m] From IEC 60287-1-1 Section 2.3.3. Mutual reactance per unit length of cable between the sheath of an outer cable and the conductors of the other two

print("X = %.10E \u03A9/m\nXm = %.10E \u03A9/m" % (X, X_m))
# Out:
# X = 5.0403313985E-05 Ω/m
# Xm = 4.3551721806E-05 Ω/m

# %%
# 4.4.3 Electrical resistance of the metal sheath at 20°C

A_s = mt.pi*d*t_s #[mm2] cross section

R_s0 = rho_s_20/(A_s*1e-6) #[Ohm/m]
print("Rs0 = %.10E \u03A9/m" % R_s0)
# Out:
# Rs0 = 1.6691286499E-04 Ω/m

# %%
# 4.4.4 Thermal resistance between conductor and sheath

t_1 = thk[1:4] #[mm] insulation thickness
d_c_arr = dia[0:3] #[mm] diameter
rho_T = [rho_sc, rho_i, rho_sc] #[Km/W] Thermal resistivity
T1_layer = [0]*len(rho_T) #[Km/W] Thermal resistance

for i in range(len(T1_layer)):
    T1_layer[i] = (rho_T[i]/(2*mt.pi))*mt.log(1+2*t_1[i]/d_c_arr[i]) #[Km/W] From IEC 60287-2-1 Section 4.1.2.1

T1 = sum(T1_layer) #[Km/W]
print("T1 = %.10f Km/W" % T1)
# Out:
# T1 = 0.4198714890 Km/W

# %%
# 4.4.5 Thermal resistance of the oversheath

t_3 = thk[5] #[mm] oversheath thickness
D_a = dia[4] #[mm] reference diameter

T3 = (1/(2*mt.pi))*rho_Tos*mt.log(1+2*t_3/D_a) #[Km/W] From IEC 60287-2-1 Section 4.1.4.1
# T3 = 1.6*T3 #[Km/W] From IEC 60287-2-1 Section 4.2.4.3.2
# The 1,6 multiplication factor for T3 of touching cables in trefoil formation only applies to buried cables (IEC 60287-2-1 Section 4.2.4.3).
print("T3 = %.10f Km/W" % T3)
# Out:
# T3 = 0.0541996092 Km/W

# %%
# 4.4.7 Dielectric losses

U_0 = U/mt.sqrt(3)*1e3 #[V]

W_d = omega*C*U_0**2*tan_delta #[W/m] From IEC 60287-1-1 Section 2.2
print("Wd = %.10f W/m" % W_d)
# Out:
# Wd = 0.3851382172 W/m

# %%
# 4.10.2.2 Heat dissipation coefficient 

D_e = dia[5]*1e-3 #[m] External diameter in meters
h = Z/(D_e**g) + E #[W/(m^2 K^(5/4)] From IEC 60287-2-1 Section 4.2.1.1
print("h = %.10f W/(m^2 K^(5/4))" % h)
# Out:
# h = 3.1327826671 W/(m^2 K^(5/4))

# %% [markdown]
# ## 4.5 case #0-1: Results dependent on the temperature
# ### 4.5.1  Results linked to the maximum operating temperature
# ### 4.5.2 First iteration & 4.5.3 Next iterations

# %%
# Criteria of convergence
tempTol = 1e-11 #[K] Temperature tolerance threshold for convergence
currTol = 1e-11 #[A] Current tolerance threshold for convergence
maxIte = 200 # Maximum number of iterations

# Other parameters
n = 1 # Single-core cable
d_c = dia[0] # Conductor diameter
lambda_2 = 0 # The cable is unarmoured
T2 = 0 # The cable is unarmoured
W_a = 0 # The cable is unarmoured
# NOTE: IEC ArmoUred Cable is not the same that NEC(NFPA 70) Armored Cable (Type AC - Article 320), which is similar to Metal-Clad Cable (Type MC Article 330)

# Variable Preallocation
R = np.zeros((maxIte,NC)) #[Ohm/m] AC resistance of conductor
R_s = np.zeros((maxIte,NC)) #[Ohm/m] Resistance of sheath
lambda_1 = np.zeros((maxIte,NC)) # Loss factor
I = np.zeros((maxIte,NC)) #[A] Current rating
W_c = np.zeros((maxIte,NC)) #[W/m] Conductor losses 
W_s = np.zeros((maxIte,NC)) #[W/m] Sheath losses
theta_c = np.zeros((maxIte,NC)) #[°C] Conductor operation temperature
theta_s = np.zeros((maxIte,NC)) #[°C] Sheath temperature

# Initial values
theta_c[0] = theta_c_max # Maximum allowable conductor temperature
theta_s[0] = theta_c_max-10 # Assumption to initializate!
Delta_theta_tr = theta_air # Morello [17]
frrt_Delta_theta_s0 = np.ones(NC)*2 # From IEC 60287-2-1 Section 4.2.1.1

for i in range(maxIte):
    print("Iteration: %2d" % (i+1))
    # 4.5.1  Results linked to the maximum operating temperature
    # 4.5.1.1 DC resistance of conductor
    R_prime = R_0*(1+alpha_20*(theta_c[i]-20)) #[Ohm/m] From IEC 60287-1-1 Section 2.1.1
    #print("R' = %.10E W/m" % R_prime[0])
    
    # 4.5.1.2 Skin effect factor
    x_s = np.sqrt(8*mt.pi*f/R_prime*1e-7*k_s) # From IEC 60287-1-1 Section 2.1.2
    # For 0 < x_s <= 2,8
    y_s = x_s**4/(192+0.8*x_s**4)
    #print("xs = %.10f\nys = %.10f" % (x_s[0], y_s[0]))

    # 4.5.1.3 Proximity effect factor 
    x_p = np.sqrt(8*mt.pi*f/R_prime*1e-7*k_p) # From IEC 60287-1-1 Section 2.1.4.1
    y_p = x_p**4/(192+0.8*x_p**4)*(d_c/s)**2*(0.312*(d_c/s)**2+1.18/(x_p**4/(192+0.8*x_p**4)+0.27))
    #print("xp = %.10f\nyp = %.10f" % (x_p[0], y_p[0]))
    
    # 4.5.1.4 AC resistance of conductor 
    R[i] = R_prime*(1+y_s+y_p) #[Ohm/m] From IEC 60287-1-1 Section 2.1
    print("R = %.10E Ohm/m" % R[i][0])
    
    # 4.5.2 First iteration & 4.5.3 Next iterations
    # 4.5.2.1 Resistance of sheath at operating temperature
    R_s[i] = R_s0*(1+alpha_s_20*(theta_s[i]-20)) #[Ohm/m] From IEC 60287-1-1 Section 2.3
    print("Rs = %.10E Ohm/m" % R_s[i][0])
    
    # 4.10.3.2 Losses caused by circulating currents (4.8.2.3)
    # For three single-core cables in flat formation, without transposition, with sheaths bonded at both ends,
    # the resistance of the sheath or screen at its operating temperaturehas a different formula for each phase,
    # based on the intermediate variables P and Q:
    P = X + X_m #[Ohm/m] From IEC 60287-1-1 Section 2.3.3
    Q = X - X_m/3 #[Ohm/m]
    
    lambda_1m_prime = (R_s[i][1]/R[i][1])*(Q**2/(R_s[i][1]**2+Q**2)) # From IEC 60287-1-1 Section 2.3.3
    lambda_11_prime = (R_s[i][0]/R[i][0])*(0.75*P**2/(R_s[i][0]**2+P**2)+0.25*Q**2/(R_s[i][0]**2+Q**2)+2*R_s[i][0]*P*Q*X_m/(mt.sqrt(3)*(R_s[i][0]**2+P**2)*(R_s[i][0]**2+Q**2)))
    lambda_12_prime = (R_s[i][2]/R[i][2])*(0.75*P**2/(R_s[i][2]**2+P**2)+0.25*Q**2/(R_s[i][2]**2+Q**2)-2*R_s[i][2]*P*Q*X_m/(mt.sqrt(3)*(R_s[i][2]**2+P**2)*(R_s[i][2]**2+Q**2)))
    
    lambda_1_prime = np.array([lambda_11_prime, lambda_1m_prime, lambda_12_prime]) # Array of loss factor
    
    # 4.10.7 Variant with non-neglected eddy-current losses 
    # 4.8.5.1 Losses caused by eddy currents (Dielectric losses taken into account) (4.6.3.1)
    rho_s = rho_s_20*(1+alpha_s_20*(theta_s[i]-20)) #[Ohm/m]
    
    beta_1 = np.sqrt(4*np.pi*omega/(1e7*rho_s)) # From IEC 60287-1-1 Section 2.3.6.1
    m = (omega/R_s[i])*1e-7
    D_s = dia[4] # Diameter after metal sheath
    g_s = 1 + (t_s/D_s)**1.74*(beta_1*D_s*1e-3-1.6) # From IEC 60287-1-1 Section 2.3.6.1
    # For cables in flat formation
    # Centre cable:
    lambda_0_m = 6*(m[1]**2/(1+m[1]**2))*(d/(2*s))**2 # From IEC 60287-1-1 Section 2.3.6.1 (2.a)
    Delta_1_m = (0.86*m[1]**3.08)*(d/(2*s))**(1.4*m[1]+0.7)
    Delta_2_m = 0
    
    # Outer cable leading phase:
    lambda_0_2 = 1.5*(m[2]**2/(1+m[2]**2))*(d/(2*s))**2 # From IEC 60287-1-1 Section 2.3.6.1 (2.b)
    Delta_1_2 = (4.7*m[2]**0.7)*(d/(2*s))**(0.16*m[2]+2)
    Delta_2_2 = (21*m[2]**3.3)*(d/(2*s))**(1.47*m[2]+5.06)
    
    # Outer cable lagging phase:
    lambda_0_1 = 1.5*(m[0]**2/(1+m[0]**2))*(d/(2*s))**2 # From IEC 60287-1-1 Section 2.3.6.1 (2.c)
    Delta_1_1 = -((0.74*(m[0]+2)*m[0]**0.5)/(2+(m[0]-0.3)**2))*(d/(2*s))**(m[0]+1)
    Delta_2_1 = (0.92*m[0]**3.7)*(d/(2*s))**(m[0]+2)
    
    # Arrays
    lambda_0 = np.array([lambda_0_1, lambda_0_m, lambda_0_2])
    Delta_1 = np.array([Delta_1_1, Delta_1_m, Delta_1_2])
    Delta_2 = np.array([Delta_2_1, Delta_2_m, Delta_2_2])
    
    lambda_1_prime2 = R_s[i]/R[i]*(g_s*lambda_0*(1+Delta_1+Delta_2)+((beta_1*t_s)**4/12e12))
    
    # 4.10.7.1 Reduction of the eddy currents losses by the circulating currents (4.8.6.1)
    M = R_s[i]/(X+X_m) # From IEC 60287-1-1 Section 2.3.5
    N = R_s[i]/(X-X_m/3) # For cables in flat formation with equidistant spacing. 
    F = (4*M**2*N**2+(M+N)**2)/(4*(M**2+1)*(N**2+1))
    
    lambda_1_prime2 = F*lambda_1_prime2
    
    lambda_1[i] = lambda_1_prime+lambda_1_prime2
    print("\u03BB1 = %.10f" % lambda_1[i][0])
    
    # 4.10.3.4 Heating due to dielectric losses (4.9.3.2)
    Delta_theta_d = W_d*(((1/(1+lambda_1[i])+lambda_2)-1/2)*T1-(n*lambda_2*T2/(1+lambda_1[i]+lambda_2))) #[K] From IEC 60287-2-1 Section 4.2.1.1
    
    # 4.10.3.5 KA factor (4.9.3.3)
    K_A = (mt.pi*D_e*h/(1+lambda_1[i]+lambda_2))*(T1/n+T2*(1+lambda_1[i])+T3*(1+lambda_1[i]+lambda_2)) #[K^(-1/4)] From IEC 60287-2-1 Section 4.2.1.1
           
    # 4.10.3.6 Cable surface temperature
    # Iterative method described in Section 4.9.6.4 -> Section 4.9.3.5.
    #Delta_theta = theta_c[i] - (theta_a + Delta_theta_tr) # IEC 60287-2-1 rating is “calculated as for a cable in free air, but the ambient temperature shall be increased by Delta_theta_tr
    Delta_theta = theta_c_max - (theta_a + theta_air) # Always keep theta_c = 90°C and Delta_theta_tr 25°C for convergence?
    Delta_theta_ds = 0 # The cables are being protected by the trough cover and hence no direct solar radiation is considered
    
    Tol2 = 1e-12 # Tolerance threshold for convergence
    maxIte2 = 20 # Maximum number of iterations
                  
    for j in range(maxIte2):
        frrt_Delta_theta_s = ((Delta_theta+Delta_theta_d+Delta_theta_ds)/(1+K_A*frrt_Delta_theta_s0))**0.25 #[K^(1/4)] From IEC 60287-2-1 Section 4.2.1.2
        error = abs(frrt_Delta_theta_s-frrt_Delta_theta_s0)
            
        if all(error < Tol2):
            print("Convergence reached after %2d iterations for cable surface temperature" % (j+1))
            break
        elif j+1 == maxIte2:
            print("Convergence criteria not reached after %2d iterations for cable surface temperature" % maxIte2)
        else:
            frrt_Delta_theta_s0 = frrt_Delta_theta_s # Update for next iteration
        
    # 4.10.3.7 External thermal resistance (4.9.3.6)
    T4 = 1/(mt.pi*D_e*h*frrt_Delta_theta_s) #[Km/W] From IEC 60287-2-1 Section 4.2.1.1
    
    # 4.10.3.8 Permissible current rating (4.5.2.3)
    #Delta_theta = theta_c[i] - theta_a
    Delta_theta = theta_c_max - theta_a # Always keep 90°C for convergence?
    I[i] = np.sqrt((Delta_theta-W_d*(0.5*T1+n*(T2+T3+T4))-Delta_theta_tr)/(R[i]*T1+n*R[i]*(1+lambda_1[i])*T2+n*R[i]*(1+lambda_1[i]+lambda_2)*(T3+T4))) #[A] From IEC 60287-1-1 Section 1.4.1.1
    print("I = %.10f A" % I[i][0])
    
    # 4.10.3.9 Losses in conductor and sheath (4.5.2.4)
    W_c[i] = R[i][0]*I[i][0]**2 #[W/m] Only consider the current in the cable 11, why?
    W_s[i] = lambda_1[i]*W_c[i] #[W/m] 
    print("Wc = %.10f W/m\nWs = %.10f W/m" % (W_c[i][0], W_s[i][0]))
    
    # 4.10.3.11 Heating of the air inside the trough
    W_TOT_i = W_c[i]+W_d+W_s[i]+W_a
    W_TOT = sum(W_TOT_i)
    
    Delta_theta_tr = W_TOT/(3*p)
    
    # 4.10.3.10 Temperature on cable components (4.5.2.5)
    theta_j = theta_a + n*(W_c[i]+W_s[i]+W_d)*T4 + Delta_theta_tr #[°C] Jacket. From IEC 60287-1-1 Section 1.4.1.1
    theta_s[i] = theta_j + n*(W_c[i]+W_s[i]+W_d)*T3 #[°C] Metal sheath
    theta_c[i] = theta_s[i] + n*(W_c[i]+W_d/2)*T1 #[°C] Conductor
    print("\u03B8j = %.10f °C\n\u03B8s = %.10f °C\n\u03B8c = %.10f °C" % (theta_j[0], theta_s[i][0], theta_c[i][0]))
    
    # Convergence evaluation
    Delta_theta_s = abs(theta_s[i] - theta_s[i-1])
    Delta_theta_c = abs(theta_c[i] - theta_c[i-1])
    Delta_theta1 = np.maximum(Delta_theta_s, Delta_theta_c)
    Delta_I = abs(I[i] - I[i-1])
    
    if all(Delta_theta1 < tempTol) and all(Delta_I < currTol):
        print("Convergence reached after %2d iterations" % (i+1))
        break
    elif i+1 == maxIte:
        print("Convergence criteria not reached after %2d iterations" % maxIte)
    else:
        theta_s[i+1] = theta_s[i] # Update for next iteration
        theta_c[i+1] = theta_c[i]
# Out:
# Iteration:  1
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0727239574E-04 Ohm/m
# λ1 = 0.8167187646
# Convergence reached after 13 iterations for cable surface temperature
# I = 794.2632582846 A
# Wc = 24.9323178820 W/m
# Ws = 20.3626918599 W/m
# θj = 83.4465796771 °C
# θs = 85.9224258467 °C
# θc = 96.4716495593 °C
# Iteration:  2
# R = 4.0188694612E-05 Ohm/m
# Rs = 2.1125616787E-04 Ohm/m
# λ1 = 0.7914738762
# Convergence reached after 10 iterations for cable surface temperature
# I = 724.0436592571 A
# Wc = 21.0684899369 W/m
# Ws = 16.6751593970 W/m
# θj = 73.9885015023 °C
# θs = 76.0550668885 °C
# θc = 84.9819794084 °C
# Iteration:  3
# R = 3.9005193467E-05 Ohm/m
# Rs = 2.0461880159E-04 Ohm/m
# λ1 = 0.8356996787
# Convergence reached after 11 iterations for cable surface temperature
# I = 781.8852505039 A
# Wc = 23.8456122512 W/m
# Ws = 19.9277704957 W/m
# θj = 81.5197693003 °C
# θs = 83.9131438813 °C
# θc = 94.0060908825 °C
# Iteration:  4
# R = 3.9934352613E-05 Ohm/m
# Rs = 2.0990460659E-04 Ohm/m
# λ1 = 0.8004756964
# Convergence reached after 11 iterations for cable surface temperature
# I = 736.0536472937 A
# Wc = 21.6354327565 W/m
# Ws = 17.3186381037 W/m
# θj = 75.5042759427 °C
# θs = 77.6364457027 °C
# θc = 86.8014013484 °C
# Iteration:  5
# R = 3.9192303798E-05 Ohm/m
# Rs = 2.0568253003E-04 Ohm/m
# λ1 = 0.8284363646
# Convergence reached after 10 iterations for cable surface temperature
# I = 772.7986031539 A
# Wc = 23.4063367887 W/m
# Ws = 19.3906605582 W/m
# θj = 80.3041246527 °C
# θs = 82.6445795265 °C
# θc = 92.5530872852 °C
# Iteration:  6
# R = 3.9784558623E-05 Ohm/m
# Rs = 2.0905129555E-04 Ohm/m
# λ1 = 0.8060152205
# Convergence reached after 10 iterations for cable surface temperature
# I = 743.5702708188 A
# Wc = 21.9967530693 W/m
# Ws = 17.7297177761 W/m
# θj = 76.4709477550 °C
# θs = 78.6449812923 °C
# θc = 87.9616450358 °C
# Iteration:  7
# R = 3.9311683738E-05 Ohm/m
# Rs = 2.0636093042E-04 Ohm/m
# λ1 = 0.8238491925
# Convergence reached after 10 iterations for cable surface temperature
# I = 766.9675808013 A
# Wc = 23.1246761446 W/m
# Ws = 19.0512457688 W/m
# θj = 79.5300334868 °C
# θs = 81.8368263149 °C
# θc = 91.6270727995 °C
# Iteration:  8
# R = 3.9689130347E-05 Ohm/m
# Rs = 2.0850795321E-04 Ohm/m
# λ1 = 0.8095715265
# Convergence reached after 10 iterations for cable surface temperature
# I = 748.3318683238 A
# Wc = 22.2259362185 W/m
# Ws = 17.9934851128 W/m
# θj = 77.0873753109 °C
# θs = 79.2881265719 °C
# θc = 88.7010177855 °C
# Iteration:  9
# R = 3.9387783543E-05 Ohm/m
# Rs = 2.0679354778E-04 Ohm/m
# λ1 = 0.8209431095
# Convergence reached after 10 iterations for cable surface temperature
# I = 763.2350286182 A
# Wc = 22.9444753065 W/m
# Ws = 18.8361089038 W/m
# θj = 79.0369661644 °C
# θs = 81.3223318434 °C
# θc = 91.0369171338 °C
# Iteration: 10
# R = 3.9628328329E-05 Ohm/m
# Rs = 2.0816187395E-04 Ohm/m
# λ1 = 0.8118485805
# Convergence reached after 10 iterations for cable surface temperature
# I = 751.3549588581 A
# Wc = 22.3715495709 W/m
# Ws = 18.1623107619 W/m
# θj = 77.4803694495 °C
# θs = 79.6981631816 °C
# θc = 89.1721932903 °C
# Iteration: 11
# R = 3.9436288974E-05 Ohm/m
# Rs = 2.0706936253E-04 Ohm/m
# λ1 = 0.8190980802
# Convergence reached after 10 iterations for cable surface temperature
# I = 760.8495217210 A
# Wc = 22.8293519878 W/m
# Ws = 18.6994783862 W/m
# θj = 78.7228439773 °C
# θs = 80.9945646968 °C
# θc = 90.6608129880 °C
# Iteration: 12
# R = 3.9589585569E-05 Ohm/m
# Rs = 2.0794139848E-04 Ohm/m
# λ1 = 0.8133040622
# Convergence reached after 10 iterations for cable surface temperature
# I = 753.2769495309 A
# Wc = 22.4641666220 W/m
# Ws = 18.2701979677 W/m
# θj = 77.7308805676 °C
# θs = 79.9595415520 °C
# θc = 89.4724589198 °C
# Iteration: 13
# R = 3.9467203951E-05 Ohm/m
# Rs = 2.0724518101E-04 Ohm/m
# λ1 = 0.8179250966
# Convergence reached after 10 iterations for cable surface temperature
# I = 759.3264868379 A
# Wc = 22.7558707497 W/m
# Ws = 18.6125977814 W/m
# θj = 78.5227007118 °C
# θs = 80.7857298820 °C
# θc = 90.4211254963 °C
# Iteration: 14
# R = 3.9564897691E-05 Ohm/m
# Rs = 2.0780092389E-04 Ohm/m
# λ1 = 0.8142333876
# Convergence reached after 10 iterations for cable surface temperature
# I = 754.4999566366 A
# Wc = 22.5231166110 W/m
# Ws = 18.3390735365 W/m
# θj = 77.8905522089 °C
# θs = 80.1261412886 °C
# θc = 89.6638100761 °C
# Iteration: 15
# R = 3.9486906835E-05 Ohm/m
# Rs = 2.0735724579E-04 Ohm/m
# λ1 = 0.8171787190
# Convergence reached after 10 iterations for cable surface temperature
# I = 758.3547433294 A
# Wc = 22.7089958068 W/m
# Ws = 18.5573081024 W/m
# θj = 78.3951698657 °C
# θs = 80.6526617534 °C
# θc = 90.2683759156 °C
# Iteration: 16
# R = 3.9549165461E-05 Ohm/m
# Rs = 2.0771141444E-04 Ohm/m
# λ1 = 0.8148263506
# Convergence reached after  9 iterations for cable surface temperature
# I = 755.2786114701 A
# Wc = 22.5606545771 W/m
# Ws = 18.3830158355 W/m
# θj = 77.9923182814 °C
# θs = 80.2323235596 °C
# θc = 89.7857534689 °C
# Iteration: 17
# R = 3.9499463651E-05 Ohm/m
# Rs = 2.0742867024E-04 Ohm/m
# λ1 = 0.8167035303
# Convergence reached after  9 iterations for cable surface temperature
# I = 757.7350042140 A
# Wc = 22.6791043450 W/m
# Ws = 18.5221045822 W/m
# θj = 78.3139036868 °C
# θs = 80.5678674519 °C
# θc = 90.1710310416 °C
# Iteration: 18
# R = 3.9539139975E-05 Ohm/m
# Rs = 2.0765437680E-04 Ohm/m
# λ1 = 0.8152045278
# Convergence reached after  9 iterations for cable surface temperature
# I = 755.7745318052 A
# Wc = 22.5845647093 W/m
# Ws = 18.4110394102 W/m
# θj = 78.0571760436 °C
# θs = 80.2999961085 °C
# θc = 89.8634652005 °C
# Iteration: 19
# R = 3.9507466087E-05 Ohm/m
# Rs = 2.0747419078E-04 Ohm/m
# λ1 = 0.8164008898
# Convergence reached after  9 iterations for cable surface temperature
# I = 757.3398669469 A
# Wc = 22.6600474020 W/m
# Ws = 18.4996828626 W/m
# θj = 78.2621170858 °C
# θs = 80.5138327236 °C
# θc = 90.1089948462 °C
# Iteration: 20
# R = 3.9532751076E-05 Ohm/m
# Rs = 2.0761802987E-04 Ohm/m
# λ1 = 0.8154456521
# Convergence reached after  9 iterations for cable surface temperature
# I = 756.0904500135 A
# Wc = 22.5997972579 W/m
# Ws = 18.4289064114 W/m
# θj = 78.0985103388 °C
# θs = 80.3431243863 °C
# θc = 89.9129891912 °C
# Iteration: 21
# R = 3.9512565972E-05 Ohm/m
# Rs = 2.0750320139E-04 Ohm/m
# λ1 = 0.8162080993
# Convergence reached after  9 iterations for cable surface temperature
# I = 757.0879765965 A
# Wc = 22.6478996617 W/m
# Ws = 18.4853991369 W/m
# θj = 78.2291156191 °C
# θs = 80.4793986818 °C
# θc = 90.0694603146 °C
# Iteration: 22
# R = 3.9528679615E-05 Ohm/m
# Rs = 2.0759486750E-04 Ohm/m
# λ1 = 0.8155993642
# Convergence reached after  9 iterations for cable surface temperature
# I = 756.2917289379 A
# Wc = 22.6095026662 W/m
# Ws = 18.4402960004 W/m
# θj = 78.1248525669 °C
# θs = 80.3706099550 °C
# θc = 89.9445497842 °C
# Iteration: 23
# R = 3.9515816065E-05 Ohm/m
# Rs = 2.0752168980E-04 Ohm/m
# λ1 = 0.8160852687
# Convergence reached after  9 iterations for cable surface temperature
# I = 756.9274204892 A
# Wc = 22.6401568777 W/m
# Ws = 18.4762985100 W/m
# θj = 78.2080848892 °C
# θs = 80.4574550455 °C
# θc = 90.0442657041 °C
# Iteration: 24
# R = 3.9526084978E-05 Ohm/m
# Rs = 2.0758010692E-04 Ohm/m
# λ1 = 0.8156973417
# Convergence reached after  9 iterations for cable surface temperature
# I = 756.4199799200 A
# Wc = 22.6156869208 W/m
# Ws = 18.4475557011 W/m
# θj = 78.1416402308 °C
# θs = 80.3881262760 °C
# θc = 89.9646626974 °C
# Iteration: 25
# R = 3.9517887299E-05 Ohm/m
# Rs = 2.0753347231E-04 Ohm/m
# λ1 = 0.8160070038
# Convergence reached after  9 iterations for cable surface temperature
# I = 756.8250885159 A
# Wc = 22.6352220395 W/m
# Ws = 18.4704997173 W/m
# θj = 78.1946826054 °C
# θs = 80.4434710031 °C
# θc = 90.0282096639 °C
# Iteration: 26
# R = 3.9524431477E-05 Ohm/m
# Rs = 2.0757070043E-04 Ohm/m
# λ1 = 0.8157597887
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.5017035723 A
# Wc = 22.6196276946 W/m
# Ws = 18.4521827092 W/m
# θj = 78.1523387912 °C
# θs = 80.3992892069 °C
# θc = 89.9774802468 °C
# Iteration: 27
# R = 3.9519207262E-05 Ohm/m
# Rs = 2.0754098116E-04 Ohm/m
# λ1 = 0.8159571322
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.7598692004 A
# Wc = 22.6320769558 W/m
# Ws = 18.4668046096 W/m
# θj = 78.1861416704 °C
# θs = 80.4345593325 °C
# θc = 90.0179774622 °C
# Iteration: 28
# R = 3.9523377738E-05 Ohm/m
# Rs = 2.0756470592E-04 Ohm/m
# λ1 = 0.8157995882
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.5537811225 A
# Wc = 22.6221389379 W/m
# Ws = 18.4551316308 W/m
# θj = 78.1591568181 °C
# θs = 80.4064031726 °C
# θc = 89.9856486120 °C
# Iteration: 29
# R = 3.9520048450E-05 Ohm/m
# Rs = 2.0754576643E-04 Ohm/m
# λ1 = 0.8159253522
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.7183041218 A
# Wc = 22.6300725713 W/m
# Ws = 18.4644499321 W/m
# θj = 78.1806987325 °C
# θs = 80.4288801351 °C
# θc = 90.0114566809 °C
# Iteration: 30
# R = 3.9522706212E-05 Ohm/m
# Rs = 2.0756088576E-04 Ohm/m
# λ1 = 0.8158249530
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.5869677664 A
# Wc = 22.6237392491 W/m
# Ws = 18.4570110098 W/m
# θj = 78.1635018302 °C
# θs = 80.4109367826 °C
# θc = 89.9908541470 °C
# Iteration: 31
# R = 3.9520584524E-05 Ohm/m
# Rs = 2.0754881600E-04 Ohm/m
# λ1 = 0.8159051002
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.6918146685 A
# Wc = 22.6287951824 W/m
# Ws = 18.4629494002 W/m
# θj = 78.1772300686 °C
# θs = 80.4252609090 °C
# θc = 90.0073011156 °C
# Iteration: 32
# R = 3.9522278263E-05 Ohm/m
# Rs = 2.0755845125E-04 Ohm/m
# λ1 = 0.8158411180
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.6081164090 A
# Wc = 22.6247590736 W/m
# Ws = 18.4582087372 W/m
# θj = 78.1662708278 °C
# θs = 80.4138259706 °C
# θc = 89.9941715302 °C
# Iteration: 33
# R = 3.9520926153E-05 Ohm/m
# Rs = 2.0755075944E-04 Ohm/m
# λ1 = 0.8158921943
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.6749331192 A
# Wc = 22.6279811139 W/m
# Ws = 18.4619931644 W/m
# θj = 78.1750195630 °C
# θs = 80.4229544536 °C
# θc = 90.0046528561 °C
# Iteration: 34
# R = 3.9522005540E-05 Ohm/m
# Rs = 2.0755689979E-04 Ohm/m
# λ1 = 0.8158514199
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.6215937969 A
# Wc = 22.6254089785 W/m
# Ws = 18.4589720399 W/m
# θj = 78.1680354581 °C
# θs = 80.4156671962 °C
# θc = 89.9962856323 °C
# Iteration: 35
# R = 3.9521143867E-05 Ohm/m
# Rs = 2.0755199796E-04 Ohm/m
# λ1 = 0.8158839698
# Convergence reached after  8 iterations for cable surface temperature
# I = 756.6641747025 A
# Wc = 22.6274623185 W/m
# Ws = 18.4613837838 W/m
# θj = 78.1736108538 °C
# θs = 80.4214845977 °C
# θc = 90.0029651728 °C
# Iteration: 36
# R = 3.9521831739E-05 Ohm/m
# Rs = 2.0755591108E-04 Ohm/m
# λ1 = 0.8158579851
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6301825782 A
# Wc = 22.6258231463 W/m
# Ws = 18.4594584836 W/m
# θj = 78.1691600231 °C
# θs = 80.4168405740 °C
# θc = 89.9976329074 °C
# Iteration: 37
# R = 3.9521282612E-05 Ohm/m
# Rs = 2.0755278724E-04 Ohm/m
# λ1 = 0.8158787286
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6573185202 A
# Wc = 22.6271316982 W/m
# Ws = 18.4609954415 W/m
# θj = 78.1727131122 °C
# θs = 80.4205478886 °C
# θc = 90.0018896457 °C
# Iteration: 38
# R = 3.9521720979E-05 Ohm/m
# Rs = 2.0755528100E-04 Ohm/m
# λ1 = 0.8158621690
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6356560012 A
# Wc = 22.6260870858 W/m
# Ws = 18.4597684869 W/m
# θj = 78.1698766866 °C
# θs = 80.4175883449 °C
# θc = 89.9984914990 °C
# Iteration: 39
# R = 3.9521371031E-05 Ohm/m
# Rs = 2.0755329023E-04 Ohm/m
# λ1 = 0.8158753885
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6529491883 A
# Wc = 22.6269209995 W/m
# Ws = 18.4607479602 W/m
# θj = 78.1721409997 °C
# θs = 80.4199509430 °C
# θc = 90.0012042336 °C
# Iteration: 40
# R = 3.9521650394E-05 Ohm/m
# Rs = 2.0755487946E-04 Ohm/m
# λ1 = 0.8158648354
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6391440900 A
# Wc = 22.6262552885 W/m
# Ws = 18.4599660468 W/m
# θj = 78.1703334022 °C
# θs = 80.4180648847 °C
# θc = 89.9990386623 °C
# Iteration: 41
# R = 3.9521427379E-05 Ohm/m
# Rs = 2.0755361078E-04 Ohm/m
# λ1 = 0.8158732599
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6501646905 A
# Wc = 22.6267867250 W/m
# Ws = 18.4605902459 W/m
# θj = 78.1717764040 °C
# θs = 80.4195705215 °C
# θc = 90.0007674342 °C
# Iteration: 42
# R = 3.9521605411E-05 Ohm/m
# Rs = 2.0755462356E-04 Ohm/m
# λ1 = 0.8158665346
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6413669736 A
# Wc = 22.6263624806 W/m
# Ws = 18.4600919482 W/m
# θj = 78.1706244580 °C
# θs = 80.4183685741 °C
# θc = 89.9993873586 °C
# Iteration: 43
# R = 3.9521463289E-05 Ohm/m
# Rs = 2.0755381506E-04 Ohm/m
# λ1 = 0.8158719034
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6483901816 A
# Wc = 22.6267011544 W/m
# Ws = 18.4604897380 W/m
# θj = 78.1715440544 °C
# θs = 80.4193280865 °C
# θc = 90.0004890705 °C
# Iteration: 44
# R = 3.9521576745E-05 Ohm/m
# Rs = 2.0755446049E-04 Ohm/m
# λ1 = 0.8158676175
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6427835706 A
# Wc = 22.6264307918 W/m
# Ws = 18.4601721829 W/m
# θj = 78.1708099421 °C
# θs = 80.4185621094 °C
# θc = 89.9996095758 °C
# Iteration: 45
# R = 3.9521486173E-05 Ohm/m
# Rs = 2.0755394524E-04 Ohm/m
# λ1 = 0.8158710389
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6472593208 A
# Wc = 22.6266466219 W/m
# Ws = 18.4604256864 W/m
# θj = 78.1713959826 °C
# θs = 80.4191735876 °C
# θc = 90.0003116749 °C
# Iteration: 46
# R = 3.9521558476E-05 Ohm/m
# Rs = 2.0755435656E-04 Ohm/m
# λ1 = 0.8158683076
# Convergence reached after  7 iterations for cable surface temperature
# I = 756.6436863387 A
# Wc = 22.6264743252 W/m
# Ws = 18.4602233149 W/m
# θj = 78.1709281475 °C
# θs = 80.4186854456 °C
# θc = 89.9997511904 °C
# Iteration: 47
# R = 3.9521500757E-05 Ohm/m
# Rs = 2.0755402821E-04 Ohm/m
# λ1 = 0.8158704880
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6465386451 A
# Wc = 22.6266118694 W/m
# Ws = 18.4603848677 W/m
# θj = 78.1713016194 °C
# θs = 80.4190751285 °C
# θc = 90.0001986242 °C
# Iteration: 48
# R = 3.9521546834E-05 Ohm/m
# Rs = 2.0755429033E-04 Ohm/m
# λ1 = 0.8158687474
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6442616545 A
# Wc = 22.6265020681 W/m
# Ws = 18.4602559003 W/m
# θj = 78.1710034774 °C
# θs = 80.4187640453 °C
# θc = 89.9998414386 °C
# Iteration: 49
# R = 3.9521510051E-05 Ohm/m
# Rs = 2.0755408108E-04 Ohm/m
# λ1 = 0.8158701369
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6460793725 A
# Wc = 22.6265897223 W/m
# Ws = 18.4603588547 W/m
# θj = 78.1712414837 °C
# θs = 80.4190123824 °C
# θc = 90.0001265793 °C
# Iteration: 50
# R = 3.9521539415E-05 Ohm/m
# Rs = 2.0755424812E-04 Ohm/m
# λ1 = 0.8158690277
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6446282917 A
# Wc = 22.6265197481 W/m
# Ws = 18.4602766664 W/m
# θj = 78.1710514837 °C
# θs = 80.4188141353 °C
# θc = 89.9998989520 °C
# Iteration: 51
# R = 3.9521515973E-05 Ohm/m
# Rs = 2.0755411477E-04 Ohm/m
# λ1 = 0.8158699132
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6457866871 A
# Wc = 22.6265756084 W/m
# Ws = 18.4603422772 W/m
# θj = 78.1712031603 °C
# θs = 80.4189723956 °C
# θc = 90.0000806665 °C
# Iteration: 52
# R = 3.9521534687E-05 Ohm/m
# Rs = 2.0755422123E-04 Ohm/m
# λ1 = 0.8158692063
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6448619422 A
# Wc = 22.6265310153 W/m
# Ws = 18.4602899002 W/m
# θj = 78.1710820771 °C
# θs = 80.4188460567 °C
# θc = 89.9999356041 °C
# Iteration: 53
# R = 3.9521519748E-05 Ohm/m
# Rs = 2.0755413624E-04 Ohm/m
# λ1 = 0.8158697706
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6456001645 A
# Wc = 22.6265666139 W/m
# Ws = 18.4603317126 W/m
# θj = 78.1711787377 °C
# θs = 80.4189469129 °C
# θc = 90.0000514071 °C
# Iteration: 54
# R = 3.9521531674E-05 Ohm/m
# Rs = 2.0755420409E-04 Ohm/m
# λ1 = 0.8158693201
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6450108429 A
# Wc = 22.6265381956 W/m
# Ws = 18.4602983338 W/m
# θj = 78.1711015737 °C
# θs = 80.4188663996 °C
# θc = 89.9999589618 °C
# Iteration: 55
# R = 3.9521522153E-05 Ohm/m
# Rs = 2.0755414993E-04 Ohm/m
# λ1 = 0.8158696797
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6454812974 A
# Wc = 22.6265608819 W/m
# Ws = 18.4603249801 W/m
# θj = 78.1711631736 °C
# θs = 80.4189306732 °C
# θc = 90.0000327607 °C
# Iteration: 56
# R = 3.9521529753E-05 Ohm/m
# Rs = 2.0755419316E-04 Ohm/m
# λ1 = 0.8158693926
# Convergence reached after  6 iterations for cable surface temperature
# I = 756.6451057344 A
# Wc = 22.6265427714 W/m
# Ws = 18.4603037084 W/m
# θj = 78.1711139985 °C
# θs = 80.4188793637 °C
# θc = 89.9999738472 °C
# Iteration: 57
# R = 3.9521523686E-05 Ohm/m
# Rs = 2.0755415865E-04 Ohm/m
# λ1 = 0.8158696218
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6454055457 A
# Wc = 22.6265572290 W/m
# Ws = 18.4603206895 W/m
# θj = 78.1711532549 °C
# θs = 80.4189203240 °C
# θc = 90.0000208778 °C
# Iteration: 58
# R = 3.9521528530E-05 Ohm/m
# Rs = 2.0755418620E-04 Ohm/m
# λ1 = 0.8158694389
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6451662069 A
# Wc = 22.6265456875 W/m
# Ws = 18.4603071335 W/m
# θj = 78.1711219166 °C
# θs = 80.4188876254 °C
# θc = 89.9999833333 °C
# Iteration: 59
# R = 3.9521524663E-05 Ohm/m
# Rs = 2.0755416421E-04 Ohm/m
# λ1 = 0.8158695849
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6453572706 A
# Wc = 22.6265549010 W/m
# Ws = 18.4603179553 W/m
# θj = 78.1711469339 °C
# θs = 80.4189137286 °C
# θc = 90.0000133050 °C
# Iteration: 60
# R = 3.9521527750E-05 Ohm/m
# Rs = 2.0755418176E-04 Ohm/m
# λ1 = 0.8158694683
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6452047448 A
# Wc = 22.6265475459 W/m
# Ws = 18.4603093163 W/m
# θj = 78.1711269626 °C
# θs = 80.4188928905 °C
# θc = 89.9999893787 °C
# Iteration: 61
# R = 3.9521525286E-05 Ohm/m
# Rs = 2.0755416775E-04 Ohm/m
# λ1 = 0.8158695614
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6453265059 A
# Wc = 22.6265534175 W/m
# Ws = 18.4603162128 W/m
# θj = 78.1711429056 °C
# θs = 80.4189095255 °C
# θc = 90.0000084790 °C
# Iteration: 62
# R = 3.9521527253E-05 Ohm/m
# Rs = 2.0755417894E-04 Ohm/m
# λ1 = 0.8158694871
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6452293042 A
# Wc = 22.6265487302 W/m
# Ws = 18.4603107073 W/m
# θj = 78.1711301784 °C
# θs = 80.4188962458 °C
# θc = 89.9999932312 °C
# Iteration: 63
# R = 3.9521525682E-05 Ohm/m
# Rs = 2.0755417000E-04 Ohm/m
# λ1 = 0.8158695464
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6453069002 A
# Wc = 22.6265524721 W/m
# Ws = 18.4603151023 W/m
# θj = 78.1711403385 °C
# θs = 80.4189068470 °C
# θc = 90.0000054035 °C
# Iteration: 64
# R = 3.9521526936E-05 Ohm/m
# Rs = 2.0755417714E-04 Ohm/m
# λ1 = 0.8158694991
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6452449554 A
# Wc = 22.6265494850 W/m
# Ws = 18.4603115938 W/m
# θj = 78.1711322277 °C
# θs = 80.4188983841 °C
# θc = 89.9999956864 °C
# Iteration: 65
# R = 3.9521525935E-05 Ohm/m
# Rs = 2.0755417144E-04 Ohm/m
# λ1 = 0.8158695369
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6452944058 A
# Wc = 22.6265518696 W/m
# Ws = 18.4603143946 W/m
# θj = 78.1711387026 °C
# θs = 80.4189051400 °C
# θc = 90.0000034435 °C
# Iteration: 66
# R = 3.9521526734E-05 Ohm/m
# Rs = 2.0755417599E-04 Ohm/m
# λ1 = 0.8158695067
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6452549297 A
# Wc = 22.6265499659 W/m
# Ws = 18.4603121587 W/m
# θj = 78.1711335337 °C
# θs = 80.4188997468 °C
# θc = 89.9999972510 °C
# Iteration: 67
# R = 3.9521526096E-05 Ohm/m
# Rs = 2.0755417236E-04 Ohm/m
# λ1 = 0.8158695308
# Convergence reached after  5 iterations for cable surface temperature
# I = 756.6452864434 A
# Wc = 22.6265514856 W/m
# Ws = 18.4603139437 W/m
# θj = 78.1711376600 °C
# θs = 80.4189040522 °C
# θc = 90.0000021945 °C
# Iteration: 68
# R = 3.9521526606E-05 Ohm/m
# Rs = 2.0755417526E-04 Ohm/m
# λ1 = 0.8158695115
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452612860 A
# Wc = 22.6265502725 W/m
# Ws = 18.4603125188 W/m
# θj = 78.1711343660 °C
# θs = 80.4189006152 °C
# θc = 89.9999982481 °C
# Iteration: 69
# R = 3.9521526199E-05 Ohm/m
# Rs = 2.0755417294E-04 Ohm/m
# λ1 = 0.8158695269
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452813691 A
# Wc = 22.6265512409 W/m
# Ws = 18.4603136563 W/m
# θj = 78.1711369956 °C
# θs = 80.4189033589 °C
# θc = 90.0000013985 °C
# Iteration: 70
# R = 3.9521526524E-05 Ohm/m
# Rs = 2.0755417479E-04 Ohm/m
# λ1 = 0.8158695146
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452653368 A
# Wc = 22.6265504678 W/m
# Ws = 18.4603127482 W/m
# θj = 78.1711348964 °C
# θs = 80.4189011686 °C
# θc = 89.9999988836 °C
# Iteration: 71
# R = 3.9521526265E-05 Ohm/m
# Rs = 2.0755417332E-04 Ohm/m
# λ1 = 0.8158695244
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452781354 A
# Wc = 22.6265510850 W/m
# Ws = 18.4603134731 W/m
# θj = 78.1711365722 °C
# θs = 80.4189029171 °C
# θc = 90.0000008912 °C
# Iteration: 72
# R = 3.9521526471E-05 Ohm/m
# Rs = 2.0755417449E-04 Ohm/m
# λ1 = 0.8158695166
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452679183 A
# Wc = 22.6265505923 W/m
# Ws = 18.4603128944 W/m
# θj = 78.1711352344 °C
# θs = 80.4189015213 °C
# θc = 89.9999992885 °C
# Iteration: 73
# R = 3.9521526306E-05 Ohm/m
# Rs = 2.0755417355E-04 Ohm/m
# λ1 = 0.8158695229
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452760746 A
# Wc = 22.6265509856 W/m
# Ws = 18.4603133564 W/m
# θj = 78.1711363023 °C
# θs = 80.4189026356 °C
# θc = 90.0000005680 °C
# Iteration: 74
# R = 3.9521526438E-05 Ohm/m
# Rs = 2.0755417430E-04 Ohm/m
# λ1 = 0.8158695179
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452695635 A
# Wc = 22.6265506716 W/m
# Ws = 18.4603129876 W/m
# θj = 78.1711354498 °C
# θs = 80.4189017460 °C
# θc = 89.9999995466 °C
# Iteration: 75
# R = 3.9521526333E-05 Ohm/m
# Rs = 2.0755417370E-04 Ohm/m
# λ1 = 0.8158695218
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452747613 A
# Wc = 22.6265509223 W/m
# Ws = 18.4603132820 W/m
# θj = 78.1711361304 °C
# θs = 80.4189024562 °C
# θc = 90.0000003620 °C
# Iteration: 76
# R = 3.9521526417E-05 Ohm/m
# Rs = 2.0755417418E-04 Ohm/m
# λ1 = 0.8158695187
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452706119 A
# Wc = 22.6265507222 W/m
# Ws = 18.4603130470 W/m
# θj = 78.1711355871 °C
# θs = 80.4189018893 °C
# θc = 89.9999997111 °C
# Iteration: 77
# R = 3.9521526350E-05 Ohm/m
# Rs = 2.0755417380E-04 Ohm/m
# λ1 = 0.8158695212
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452739243 A
# Wc = 22.6265508819 W/m
# Ws = 18.4603132346 W/m
# θj = 78.1711360208 °C
# θs = 80.4189023418 °C
# θc = 90.0000002307 °C
# Iteration: 78
# R = 3.9521526403E-05 Ohm/m
# Rs = 2.0755417410E-04 Ohm/m
# λ1 = 0.8158695192
# Convergence reached after  4 iterations for cable surface temperature
# I = 756.6452712800 A
# Wc = 22.6265507544 W/m
# Ws = 18.4603130848 W/m
# θj = 78.1711356745 °C
# θs = 80.4189019805 °C
# θc = 89.9999998159 °C
# Iteration: 79
# R = 3.9521526361E-05 Ohm/m
# Rs = 2.0755417386E-04 Ohm/m
# λ1 = 0.8158695208
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452733910 A
# Wc = 22.6265508562 W/m
# Ws = 18.4603132044 W/m
# θj = 78.1711359509 °C
# θs = 80.4189022689 °C
# θc = 90.0000001470 °C
# Iteration: 80
# R = 3.9521526395E-05 Ohm/m
# Rs = 2.0755417406E-04 Ohm/m
# λ1 = 0.8158695195
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452717058 A
# Wc = 22.6265507749 W/m
# Ws = 18.4603131089 W/m
# θj = 78.1711357303 °C
# θs = 80.4189020387 °C
# θc = 89.9999998826 °C
# Iteration: 81
# R = 3.9521526367E-05 Ohm/m
# Rs = 2.0755417390E-04 Ohm/m
# λ1 = 0.8158695205
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452730511 A
# Wc = 22.6265508398 W/m
# Ws = 18.4603131851 W/m
# θj = 78.1711359064 °C
# θs = 80.4189022225 °C
# θc = 90.0000000937 °C
# Iteration: 82
# R = 3.9521526389E-05 Ohm/m
# Rs = 2.0755417402E-04 Ohm/m
# λ1 = 0.8158695197
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452719771 A
# Wc = 22.6265507880 W/m
# Ws = 18.4603131243 W/m
# θj = 78.1711357658 °C
# θs = 80.4189020758 °C
# θc = 89.9999999252 °C
# Iteration: 83
# R = 3.9521526372E-05 Ohm/m
# Rs = 2.0755417393E-04 Ohm/m
# λ1 = 0.8158695204
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452728345 A
# Wc = 22.6265508293 W/m
# Ws = 18.4603131729 W/m
# θj = 78.1711358781 °C
# θs = 80.4189021929 °C
# θc = 90.0000000597 °C
# Iteration: 84
# R = 3.9521526386E-05 Ohm/m
# Rs = 2.0755417400E-04 Ohm/m
# λ1 = 0.8158695199
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452721500 A
# Wc = 22.6265507963 W/m
# Ws = 18.4603131341 W/m
# θj = 78.1711357885 °C
# θs = 80.4189020994 °C
# θc = 89.9999999523 °C
# Iteration: 85
# R = 3.9521526375E-05 Ohm/m
# Rs = 2.0755417394E-04 Ohm/m
# λ1 = 0.8158695203
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452726964 A
# Wc = 22.6265508227 W/m
# Ws = 18.4603131650 W/m
# θj = 78.1711358600 °C
# θs = 80.4189021741 °C
# θc = 90.0000000380 °C
# Iteration: 86
# R = 3.9521526383E-05 Ohm/m
# Rs = 2.0755417399E-04 Ohm/m
# λ1 = 0.8158695199
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452722602 A
# Wc = 22.6265508017 W/m
# Ws = 18.4603131403 W/m
# θj = 78.1711358029 °C
# θs = 80.4189021145 °C
# θc = 89.9999999696 °C
# Iteration: 87
# R = 3.9521526376E-05 Ohm/m
# Rs = 2.0755417395E-04 Ohm/m
# λ1 = 0.8158695202
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452726084 A
# Wc = 22.6265508184 W/m
# Ws = 18.4603131601 W/m
# θj = 78.1711358485 °C
# θs = 80.4189021620 °C
# θc = 90.0000000242 °C
# Iteration: 88
# R = 3.9521526382E-05 Ohm/m
# Rs = 2.0755417398E-04 Ohm/m
# λ1 = 0.8158695200
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452723305 A
# Wc = 22.6265508050 W/m
# Ws = 18.4603131443 W/m
# θj = 78.1711358121 °C
# θs = 80.4189021241 °C
# θc = 89.9999999806 °C
# Iteration: 89
# R = 3.9521526378E-05 Ohm/m
# Rs = 2.0755417396E-04 Ohm/m
# λ1 = 0.8158695202
# Convergence reached after  3 iterations for cable surface temperature
# I = 756.6452725524 A
# Wc = 22.6265508157 W/m
# Ws = 18.4603131569 W/m
# θj = 78.1711358411 °C
# θs = 80.4189021544 °C
# θc = 90.0000000155 °C
# Iteration: 90
# R = 3.9521526381E-05 Ohm/m
# Rs = 2.0755417398E-04 Ohm/m
# λ1 = 0.8158695200
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452723752 A
# Wc = 22.6265508072 W/m
# Ws = 18.4603131468 W/m
# θj = 78.1711358179 °C
# θs = 80.4189021302 °C
# θc = 89.9999999877 °C
# Iteration: 91
# R = 3.9521526378E-05 Ohm/m
# Rs = 2.0755417396E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452725166 A
# Wc = 22.6265508140 W/m
# Ws = 18.4603131549 W/m
# θj = 78.1711358365 °C
# θs = 80.4189021495 °C
# θc = 90.0000000098 °C
# Iteration: 92
# R = 3.9521526381E-05 Ohm/m
# Rs = 2.0755417398E-04 Ohm/m
# λ1 = 0.8158695200
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724038 A
# Wc = 22.6265508086 W/m
# Ws = 18.4603131485 W/m
# θj = 78.1711358217 °C
# θs = 80.4189021341 °C
# θc = 89.9999999921 °C
# Iteration: 93
# R = 3.9521526379E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724939 A
# Wc = 22.6265508129 W/m
# Ws = 18.4603131536 W/m
# θj = 78.1711358335 °C
# θs = 80.4189021464 °C
# θc = 90.0000000063 °C
# Iteration: 94
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724219 A
# Wc = 22.6265508095 W/m
# Ws = 18.4603131495 W/m
# θj = 78.1711358241 °C
# θs = 80.4189021366 °C
# θc = 89.9999999950 °C
# Iteration: 95
# R = 3.9521526379E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724793 A
# Wc = 22.6265508122 W/m
# Ws = 18.4603131527 W/m
# θj = 78.1711358316 °C
# θs = 80.4189021444 °C
# θc = 90.0000000040 °C
# Iteration: 96
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724335 A
# Wc = 22.6265508100 W/m
# Ws = 18.4603131502 W/m
# θj = 78.1711358256 °C
# θs = 80.4189021381 °C
# θc = 89.9999999968 °C
# Iteration: 97
# R = 3.9521526379E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724701 A
# Wc = 22.6265508118 W/m
# Ws = 18.4603131522 W/m
# θj = 78.1711358304 °C
# θs = 80.4189021431 °C
# θc = 90.0000000025 °C
# Iteration: 98
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724409 A
# Wc = 22.6265508104 W/m
# Ws = 18.4603131506 W/m
# θj = 78.1711358265 °C
# θs = 80.4189021391 °C
# θc = 89.9999999980 °C
# Iteration: 99
# R = 3.9521526379E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724642 A
# Wc = 22.6265508115 W/m
# Ws = 18.4603131519 W/m
# θj = 78.1711358296 °C
# θs = 80.4189021423 °C
# θc = 90.0000000016 °C
# Iteration: 100
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724456 A
# Wc = 22.6265508106 W/m
# Ws = 18.4603131508 W/m
# θj = 78.1711358272 °C
# θs = 80.4189021398 °C
# θc = 89.9999999987 °C
# Iteration: 101
# R = 3.9521526379E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  2 iterations for cable surface temperature
# I = 756.6452724605 A
# Wc = 22.6265508113 W/m
# Ws = 18.4603131517 W/m
# θj = 78.1711358291 °C
# θs = 80.4189021418 °C
# θc = 90.0000000010 °C
# Iteration: 102
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724486 A
# Wc = 22.6265508107 W/m
# Ws = 18.4603131510 W/m
# θj = 78.1711358276 °C
# θs = 80.4189021402 °C
# θc = 89.9999999992 °C
# Iteration: 103
# R = 3.9521526379E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724581 A
# Wc = 22.6265508112 W/m
# Ws = 18.4603131515 W/m
# θj = 78.1711358288 °C
# θs = 80.4189021415 °C
# θc = 90.0000000007 °C
# Iteration: 104
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724505 A
# Wc = 22.6265508108 W/m
# Ws = 18.4603131511 W/m
# θj = 78.1711358278 °C
# θs = 80.4189021405 °C
# θc = 89.9999999995 °C
# Iteration: 105
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724565 A
# Wc = 22.6265508111 W/m
# Ws = 18.4603131515 W/m
# θj = 78.1711358286 °C
# θs = 80.4189021413 °C
# θc = 90.0000000004 °C
# Iteration: 106
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724517 A
# Wc = 22.6265508109 W/m
# Ws = 18.4603131512 W/m
# θj = 78.1711358280 °C
# θs = 80.4189021406 °C
# θc = 89.9999999997 °C
# Iteration: 107
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724556 A
# Wc = 22.6265508111 W/m
# Ws = 18.4603131514 W/m
# θj = 78.1711358285 °C
# θs = 80.4189021411 °C
# θc = 90.0000000003 °C
# Iteration: 108
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724525 A
# Wc = 22.6265508109 W/m
# Ws = 18.4603131512 W/m
# θj = 78.1711358281 °C
# θs = 80.4189021407 °C
# θc = 89.9999999998 °C
# Iteration: 109
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724550 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131514 W/m
# θj = 78.1711358284 °C
# θs = 80.4189021411 °C
# θc = 90.0000000002 °C
# Iteration: 110
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724530 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358281 °C
# θs = 80.4189021408 °C
# θc = 89.9999999999 °C
# Iteration: 111
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724546 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358283 °C
# θs = 80.4189021410 °C
# θc = 90.0000000001 °C
# Iteration: 112
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724533 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021408 °C
# θc = 89.9999999999 °C
# Iteration: 113
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724543 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358283 °C
# θs = 80.4189021410 °C
# θc = 90.0000000001 °C
# Iteration: 114
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724535 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 89.9999999999 °C
# Iteration: 115
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724541 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358283 °C
# θs = 80.4189021410 °C
# θc = 90.0000000000 °C
# Iteration: 116
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724536 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 117
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724540 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358283 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 118
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724537 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 119
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724540 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358283 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 120
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724538 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 121
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358283 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 122
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724538 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 123
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 124
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724538 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 125
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 126
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724538 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 127
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 128
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724538 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 129
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 130
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 131
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 132
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 133
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 134
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Iteration: 135
# R = 3.9521526380E-05 Ohm/m
# Rs = 2.0755417397E-04 Ohm/m
# λ1 = 0.8158695201
# Convergence reached after  1 iterations for cable surface temperature
# I = 756.6452724539 A
# Wc = 22.6265508110 W/m
# Ws = 18.4603131513 W/m
# θj = 78.1711358282 °C
# θs = 80.4189021409 °C
# θc = 90.0000000000 °C
# Convergence reached after 135 iterations

# %% [markdown]
# ### Results

# %%
# Permissible current convergence plot
Iplt = I[0:i+1,0]

plt.figure()
plt.plot(list(range(1,i+2)),Iplt)
plt.xlabel('Iterations')
plt.ylabel('Permissible current [A]')
plt.show()

# %%
# Permissible current rounding
print("I3 = %.4f A, I1 = %.4f A, I2 = %.4f A" % (I[i,0], I[i,1], I[i,2]))

Imin = min(I[i,:])

if Imin < 200:
    I_rating = int(Imin)
elif Imin < 500:
    I_rating = int(Imin/5)*5
else:
    I_rating = int(Imin/10)*10
        
print("The permissible current rating of one conductor is equal to %5d A" % I_rating)
# Out:
# I3 = 756.6453 A, I1 = 855.1481 A, I2 = 780.2569 A
# The permissible current rating of one conductor is equal to   750 A
